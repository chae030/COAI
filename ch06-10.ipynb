# %% [markdown]
# [코드 6-6] 의 시각화 기능을 MNIST 데이터셋에 적용하시오. 프로그램 실행 결과로 얻은 커널과 특징 맵을 관찰하고 해석하시오.ㅍ

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.optimizers import Adam

# CIFAR-10 데이터셋을 읽고 신경망에 입력할 형태로 변환
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

# 신경망 모델 설계
cnn=Sequential()
cnn.add(Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)))
cnn.add(Conv2D(32,(3,3),activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.25))
cnn.add(Conv2D(64,(3,3),activation='relu'))
cnn.add(Conv2D(64,(3,3),activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Dropout(0.25))
cnn.add(Flatten())
cnn.add(Dense(512,activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(10,activation='softmax'))

# 신경망 모델 학습
cnn.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])
hist=cnn.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)

cnn.summary() # cnn 모델의 정보 출력

for layer in cnn.layers: # 컨볼루션층의 커널을 시각화
    if 'conv' in layer.name:
        kernel,biases=layer.get_weights()
        print(layer.name,kernel.shape) # 커널의 텐서 모양을 출력

kernel,biases=cnn.layers[0].get_weights() # 층 0의 커널 정보를 저장
minv,maxv=kernel.min(),kernel.max()
kernel=(kernel-minv)/(maxv-minv)
n_kernel=32

import matplotlib.pyplot as plt

plt.figure(figsize=(20,3))
plt.suptitle("Kernels of conv2d_4")
for i in range(n_kernel): # i번째 커널
    f=kernel[:,:,:,i]
    for j in range(3): # j번째 채널
        plt.subplot(3,n_kernel,j*n_kernel+i+1)
        plt.imshow(f[:,:,j],cmap='gray')
        plt.xticks([]); plt.yticks([])
        plt.title(str(i)+'_'+str(j))
plt.show()

for layer in cnn.layers: # 컨볼루션층의 특징 맵을 시각화
    if 'conv' in layer.name:
        print(layer.name,layer.output.shape) # 특징 맵의 텐서 모양을 출력

from tensorflow.keras.models import Model

partial_model=Model(inputs=cnn.inputs,outputs=cnn.layers[0].output) # 층 0만 떼어냄
partial_model.summary()

feature_map=partial_model.predict(x_test) # 부분 모델로 테스트 집합을 예측
fm=feature_map[1] # 1번 영상의 특징 맵을 시각화

plt.imshow(x_test[1]) # 1번 영상을 출력

plt.figure(figsize=(20,3))
plt.suptitle("Feature maps of conv2d_4")
for i in range(32): # i번째 특징 맵 
    plt.subplot(2,16,i+1)
    plt.imshow(fm[:,:,i],cmap='gray')
    plt.xticks([]); plt.yticks([])
    plt.title("map"+str(i))
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 37s 0us/step
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 391/391 - 88s - 226ms/step - accuracy: 0.3765 - loss: 1.6870 - val_accuracy: 0.5210 - val_loss: 1.3243
# Epoch 2/30
# 391/391 - 82s - 211ms/step - accuracy: 0.5465 - loss: 1.2660 - val_accuracy: 0.6133 - val_loss: 1.0844
# Epoch 3/30
# 391/391 - 74s - 190ms/step - accuracy: 0.6078 - loss: 1.1040 - val_accuracy: 0.6471 - val_loss: 0.9885
# Epoch 4/30
# 391/391 - 86s - 220ms/step - accuracy: 0.6513 - loss: 0.9891 - val_accuracy: 0.6817 - val_loss: 0.9052
# Epoch 5/30
# 391/391 - 75s - 191ms/step - accuracy: 0.6741 - loss: 0.9204 - val_accuracy: 0.7038 - val_loss: 0.8497
# Epoch 6/30
# 391/391 - 88s - 226ms/step - accuracy: 0.6989 - loss: 0.8541 - val_accuracy: 0.7256 - val_loss: 0.7863
# Epoch 7/30
# 391/391 - 92s - 236ms/step - accuracy: 0.7180 - loss: 0.7969 - val_accuracy: 0.7404 - val_loss: 0.7427
# Epoch 8/30
# 391/391 - 82s - 209ms/step - accuracy: 0.7324 - loss: 0.7591 - val_accuracy: 0.7364 - val_loss: 0.7648
# Epoch 9/30
# 391/391 - 67s - 172ms/step - accuracy: 0.7453 - loss: 0.7267 - val_accuracy: 0.7537 - val_loss: 0.7135
# Epoch 10/30
# 391/391 - 98s - 250ms/step - accuracy: 0.7539 - loss: 0.6992 - val_accuracy: 0.7569 - val_loss: 0.7034
# Epoch 11/30
# 391/391 - 71s - 182ms/step - accuracy: 0.7634 - loss: 0.6701 - val_accuracy: 0.7590 - val_loss: 0.7064
# Epoch 12/30
# 391/391 - 68s - 174ms/step - accuracy: 0.7704 - loss: 0.6492 - val_accuracy: 0.7728 - val_loss: 0.6547
# Epoch 13/30
# 391/391 - 68s - 173ms/step - accuracy: 0.7804 - loss: 0.6240 - val_accuracy: 0.7671 - val_loss: 0.6809
# Epoch 14/30
# 391/391 - 66s - 169ms/step - accuracy: 0.7866 - loss: 0.6067 - val_accuracy: 0.7771 - val_loss: 0.6409
# Epoch 15/30
# 391/391 - 66s - 170ms/step - accuracy: 0.7923 - loss: 0.5874 - val_accuracy: 0.7766 - val_loss: 0.6445
# Epoch 16/30
# 391/391 - 66s - 169ms/step - accuracy: 0.7996 - loss: 0.5681 - val_accuracy: 0.7871 - val_loss: 0.6296
# Epoch 17/30
# 391/391 - 97s - 247ms/step - accuracy: 0.8033 - loss: 0.5557 - val_accuracy: 0.7798 - val_loss: 0.6380
# Epoch 18/30
# 391/391 - 79s - 202ms/step - accuracy: 0.8087 - loss: 0.5429 - val_accuracy: 0.7881 - val_loss: 0.6341
# Epoch 19/30
# 391/391 - 80s - 205ms/step - accuracy: 0.8139 - loss: 0.5254 - val_accuracy: 0.7931 - val_loss: 0.6160
# Epoch 20/30
# 391/391 - 76s - 194ms/step - accuracy: 0.8172 - loss: 0.5134 - val_accuracy: 0.7814 - val_loss: 0.6458
# Epoch 21/30
# 391/391 - 83s - 212ms/step - accuracy: 0.8187 - loss: 0.5079 - val_accuracy: 0.7931 - val_loss: 0.6120
# Epoch 22/30
# 391/391 - 77s - 197ms/step - accuracy: 0.8243 - loss: 0.4901 - val_accuracy: 0.7906 - val_loss: 0.6234
# Epoch 23/30
# 391/391 - 84s - 214ms/step - accuracy: 0.8284 - loss: 0.4818 - val_accuracy: 0.7964 - val_loss: 0.6121
# Epoch 24/30
# 391/391 - 75s - 193ms/step - accuracy: 0.8329 - loss: 0.4720 - val_accuracy: 0.7908 - val_loss: 0.6264
# Epoch 25/30
# 391/391 - 75s - 193ms/step - accuracy: 0.8350 - loss: 0.4622 - val_accuracy: 0.7865 - val_loss: 0.6464
# Epoch 26/30
# 391/391 - 75s - 193ms/step - accuracy: 0.8413 - loss: 0.4479 - val_accuracy: 0.7936 - val_loss: 0.6287
# Epoch 27/30
# 391/391 - 88s - 226ms/step - accuracy: 0.8435 - loss: 0.4424 - val_accuracy: 0.7909 - val_loss: 0.6449
# Epoch 28/30
# 391/391 - 79s - 202ms/step - accuracy: 0.8430 - loss: 0.4380 - val_accuracy: 0.7893 - val_loss: 0.6534
# Epoch 29/30
# 391/391 - 83s - 213ms/step - accuracy: 0.8483 - loss: 0.4283 - val_accuracy: 0.7968 - val_loss: 0.6208
# Epoch 30/30
# 391/391 - 123s - 314ms/step - accuracy: 0.8512 - loss: 0.4152 - val_accuracy: 0.7954 - val_loss: 0.6315
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 10, 10, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       819,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,671,232 (10.19 MB)
#  Trainable params: 890,410 (3.40 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,780,822 (6.79 MB)
# conv2d (3, 3, 3, 32)
# conv2d_1 (3, 3, 32, 32)
# conv2d_2 (3, 3, 32, 64)
# conv2d_3 (3, 3, 64, 64)
# conv2d (None, 30, 30, 32)
# conv2d_1 (None, 28, 28, 32)
# conv2d_2 (None, 12, 12, 64)
# conv2d_3 (None, 10, 10, 64)
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 896 (3.50 KB)
#  Trainable params: 896 (3.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  66/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/models/functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 32, 32, 3))
#   warnings.warn(msg)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/models/functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 32, 32, 3))
#   warnings.warn(msg)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model

# MNIST 데이터셋 로드 및 전처리
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 28, 28, 1).astype(np.float32) / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype(np.float32) / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# CNN 모델 정의
cnn = Sequential()
cnn.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
cnn.add(Conv2D(32, (3, 3), activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))
cnn.add(Dropout(0.25))
cnn.add(Conv2D(64, (3, 3), activation='relu'))
cnn.add(Conv2D(64, (3, 3), activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))
cnn.add(Dropout(0.25))
cnn.add(Flatten())
cnn.add(Dense(512, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(10, activation='softmax'))

# 모델 컴파일 및 학습
cnn.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
hist = cnn.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test), verbose=2)

cnn.summary()

# 컨볼루션층 커널 시각화
for layer in cnn.layers:
    if 'conv' in layer.name:
        kernel, biases = layer.get_weights()
        print(layer.name, kernel.shape)

kernel, biases = cnn.layers[0].get_weights()
minv, maxv = kernel.min(), kernel.max()
kernel = (kernel - minv) / (maxv - minv)
n_kernel = 32

plt.figure(figsize=(20, 3))
plt.suptitle("Kernels of First Conv2D Layer")
for i in range(n_kernel):
    f = kernel[:, :, 0, i]  # MNIST는 채널이 1개
    plt.subplot(2, 16, i + 1)
    plt.imshow(f, cmap='gray')
    plt.xticks([]); plt.yticks([])
    plt.title(f"Kernel {i}")
plt.show()

# 특징 맵 시각화
for layer in cnn.layers:
    if 'conv' in layer.name:
        print(layer.name, layer.output.shape)

partial_model = Model(inputs=cnn.inputs, outputs=cnn.layers[0].output)
partial_model.summary()

feature_map = partial_model.predict(x_test)
fm = feature_map[1]  # 테스트 데이터의 두 번째 이미지에 대한 특징 맵

plt.imshow(x_test[1].reshape(28, 28), cmap='gray')  # 원본 이미지 출력
plt.title("Original Image")
plt.show()

plt.figure(figsize=(20, 3))
plt.suptitle("Feature Maps of First Conv2D Layer")
for i in range(32):
    plt.subplot(2, 16, i + 1)
    plt.imshow(fm[:, :, i], cmap='gray')
    plt.xticks([]); plt.yticks([])
    plt.title(f"Map {i}")
plt.show()
# Out:
# Epoch 1/10
# 469/469 - 79s - 169ms/step - accuracy: 0.9311 - loss: 0.2177 - val_accuracy: 0.9876 - val_loss: 0.0376
# Epoch 2/10
# 469/469 - 77s - 165ms/step - accuracy: 0.9809 - loss: 0.0620 - val_accuracy: 0.9916 - val_loss: 0.0256
# Epoch 3/10
# 469/469 - 72s - 153ms/step - accuracy: 0.9863 - loss: 0.0450 - val_accuracy: 0.9919 - val_loss: 0.0226
# Epoch 4/10
# 469/469 - 72s - 154ms/step - accuracy: 0.9879 - loss: 0.0388 - val_accuracy: 0.9922 - val_loss: 0.0213
# Epoch 5/10
# 469/469 - 64s - 136ms/step - accuracy: 0.9896 - loss: 0.0331 - val_accuracy: 0.9939 - val_loss: 0.0178
# Epoch 6/10
# 469/469 - 67s - 143ms/step - accuracy: 0.9910 - loss: 0.0288 - val_accuracy: 0.9945 - val_loss: 0.0168
# Epoch 7/10
# 469/469 - 65s - 139ms/step - accuracy: 0.9921 - loss: 0.0254 - val_accuracy: 0.9916 - val_loss: 0.0269
# Epoch 8/10
# 469/469 - 63s - 135ms/step - accuracy: 0.9922 - loss: 0.0236 - val_accuracy: 0.9942 - val_loss: 0.0216
# Epoch 9/10
# 469/469 - 65s - 139ms/step - accuracy: 0.9928 - loss: 0.0225 - val_accuracy: 0.9934 - val_loss: 0.0208
# Epoch 10/10
# 469/469 - 65s - 138ms/step - accuracy: 0.9938 - loss: 0.0198 - val_accuracy: 0.9954 - val_loss: 0.0164
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 24, 24, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 10, 10, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 8, 8, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,784,768 (6.81 MB)
#  Trainable params: 594,922 (2.27 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,189,846 (4.54 MB)
# conv2d_4 (3, 3, 1, 32)
# conv2d_5 (3, 3, 32, 32)
# conv2d_6 (3, 3, 32, 64)
# conv2d_7 (3, 3, 64, 64)
# conv2d_4 (None, 26, 26, 32)
# conv2d_5 (None, 24, 24, 32)
# conv2d_6 (None, 10, 10, 64)
# conv2d_7 (None, 8, 8, 64)
# Model: "functional_25"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 320 (1.25 KB)
#  Trainable params: 320 (1.25 KB)
#  Non-trainable params: 0 (0.00 B)
# 157/313 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/models/functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_79']
# Received: inputs=Tensor(shape=(32, 28, 28, 1))
#   warnings.warn(msg)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/models/functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_79']
# Received: inputs=Tensor(shape=(None, 28, 28, 1))
#   warnings.warn(msg)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model

# %%
# MNIST 데이터셋 로드 및 전처리
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1, 28, 28, 1).astype(np.float32) / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype(np.float32) / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
# CNN 모델 정의
cnn = Sequential()
cnn.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
cnn.add(Conv2D(32, (3, 3), activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))
cnn.add(Dropout(0.25))
cnn.add(Conv2D(64, (3, 3), activation='relu'))
cnn.add(Conv2D(64, (3, 3), activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))
cnn.add(Dropout(0.25))
cnn.add(Flatten())
cnn.add(Dense(512, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(10, activation='softmax'))

# %%
# 모델 컴파일 및 학습
cnn.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
hist = cnn.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test), verbose=2)

cnn.summary()
# Out:
# Epoch 1/10
# 469/469 - 101s - 215ms/step - accuracy: 0.9262 - loss: 0.2279 - val_accuracy: 0.9869 - val_loss: 0.0419
# Epoch 2/10
# 469/469 - 81s - 172ms/step - accuracy: 0.9803 - loss: 0.0644 - val_accuracy: 0.9893 - val_loss: 0.0328
# Epoch 3/10
# 469/469 - 76s - 162ms/step - accuracy: 0.9856 - loss: 0.0478 - val_accuracy: 0.9914 - val_loss: 0.0235
# Epoch 4/10
# 469/469 - 73s - 156ms/step - accuracy: 0.9877 - loss: 0.0389 - val_accuracy: 0.9951 - val_loss: 0.0168
# Epoch 5/10
# 469/469 - 81s - 172ms/step - accuracy: 0.9898 - loss: 0.0325 - val_accuracy: 0.9940 - val_loss: 0.0200
# Epoch 6/10
# 469/469 - 66s - 141ms/step - accuracy: 0.9913 - loss: 0.0280 - val_accuracy: 0.9937 - val_loss: 0.0191
# Epoch 7/10
# 469/469 - 64s - 137ms/step - accuracy: 0.9915 - loss: 0.0273 - val_accuracy: 0.9947 - val_loss: 0.0160
# Epoch 8/10
# 469/469 - 62s - 133ms/step - accuracy: 0.9920 - loss: 0.0244 - val_accuracy: 0.9934 - val_loss: 0.0190
# Epoch 9/10
# 469/469 - 68s - 145ms/step - accuracy: 0.9934 - loss: 0.0212 - val_accuracy: 0.9940 - val_loss: 0.0195
# Epoch 10/10
# 469/469 - 71s - 151ms/step - accuracy: 0.9932 - loss: 0.0219 - val_accuracy: 0.9951 - val_loss: 0.0164
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 24, 24, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 10, 10, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 8, 8, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,784,768 (6.81 MB)
#  Trainable params: 594,922 (2.27 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,189,846 (4.54 MB)

# %%
# 컨볼루션층 커널 시각화
for layer in cnn.layers:
    if 'conv' in layer.name:
        kernel, biases = layer.get_weights()
        print(layer.name, kernel.shape)

kernel, biases = cnn.layers[0].get_weights()
minv, maxv = kernel.min(), kernel.max()
kernel = (kernel - minv) / (maxv - minv)
n_kernel = 32

plt.figure(figsize=(20, 3))
plt.suptitle("Kernels of First Conv2D Layer")
for i in range(n_kernel):
    f = kernel[:, :, 0, i]  # MNIST는 채널이 1개
    plt.subplot(2, 16, i + 1)
    plt.imshow(f, cmap='gray')
    plt.xticks([]); plt.yticks([])
    plt.title(f"Kernel {i}")
plt.show()
# Out:
# conv2d_8 (3, 3, 1, 32)
# conv2d_9 (3, 3, 32, 32)
# conv2d_10 (3, 3, 32, 64)
# conv2d_11 (3, 3, 64, 64)

# %%
# 특징 맵 시각화
for layer in cnn.layers:
    if 'conv' in layer.name:
        print(layer.name, layer.output.shape)

partial_model = Model(inputs=cnn.inputs, outputs=cnn.layers[0].output)
partial_model.summary()

feature_map = partial_model.predict(x_test)
fm = feature_map[1]  # 테스트 데이터의 두 번째 이미지에 대한 특징 맵

plt.imshow(x_test[1].reshape(28, 28), cmap='gray')  # 원본 이미지 출력
plt.title("Original Image")
plt.show()

plt.figure(figsize=(20, 3))
plt.suptitle("Feature Maps of First Conv2D Layer")
for i in range(32):
    plt.subplot(2, 16, i + 1)
    plt.imshow(fm[:, :, i], cmap='gray')
    plt.xticks([]); plt.yticks([])
    plt.title(f"Map {i}")
plt.show()
# Out:
# conv2d_8 (None, 26, 26, 32)
# conv2d_9 (None, 24, 24, 32)
# conv2d_10 (None, 10, 10, 64)
# conv2d_11 (None, 8, 8, 64)
# Model: "functional_38"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 320 (1.25 KB)
#  Trainable params: 320 (1.25 KB)
#  Non-trainable params: 0 (0.00 B)
# 123/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/models/functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_158']
# Received: inputs=Tensor(shape=(32, 28, 28, 1))
#   warnings.warn(msg)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/models/functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_158']
# Received: inputs=Tensor(shape=(None, 28, 28, 1))
#   warnings.warn(msg)
